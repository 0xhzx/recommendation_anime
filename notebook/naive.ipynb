# %% [markdown]
# # Naive Approach

# %%
import pandas as pd
import numpy as np

# %%
anime = pd.read_csv('../data/anime.csv')
anime.head()
# Out:
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2       6                           Trigun  8.24
# 3       7               Witch Hunter Robin  7.27
# 4       8                   Bouken Ou Beet  6.98
#
#                                               Genres            English name  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space            Cowboy Bebop
# 1              Action, Drama, Mystery, Sci-Fi, Space  Cowboy Bebop:The Movie
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen                  Trigun
# 3  Action, Mystery, Police, Supernatural, Drama, ...      Witch Hunter Robin
# 4          Adventure, Fantasy, Shounen, Supernatural  Beet the Vandel Buster
#
#                       Japanese name   Type Episodes  \
# 0                         カウボーイビバップ     TV       26
# 1                    カウボーイビバップ 天国の扉  Movie        1
# ...

# %%
# find out how many unique genres there are
genres = anime['Genres'].str.split(', ')
unique_genres = set()
for genre_list in genres:
    for genre in genre_list:
        unique_genres.add(genre)
unique_genres = list(unique_genres)
unique_genres.sort()

# %%
def recommend(genre_list, anime, k):
    # support multiple genres
    unique_anime_list = set()
    for genre in genre_list:
        for i in range(len(anime)):
            if genre in anime['Genres'][i]:
                unique_anime_list.add(anime['Name'][i])
                
    unique_anime_list = list(unique_anime_list)
    # filter out the anime that in the unique_anime_list
    anime = anime[anime['Name'].isin(unique_anime_list)]
    # drop score = unknown
    anime = anime[anime['Score'] != 'Unknown']
    anime = anime.sort_values(by='Score', ascending=False)
    return anime.head(k)

# test
genre_list = ['Action', 'Millitary', 'Adventure']
recommend(genre_list, anime=anime, k=10)
# Out:
#        MAL_ID                                               Name Score  \
# 3971     5114                   Fullmetal Alchemist: Brotherhood  9.19
# 15926   40028               Shingeki no Kyojin: The Final Season  9.17
# 9913    28977                                           Gintama°   9.1
# 14963   38524                 Shingeki no Kyojin Season 3 Part 2   9.1
# 6474    11061                             Hunter x Hunter (2011)   9.1
# 6006     9969                                           Gintama'  9.08
# 7261    15417                                Gintama': Enchousen  9.04
# 12242   34096                                           Gintama.  8.99
# 7249    15335  Gintama Movie 2: Kanketsu-hen - Yorozuya yo Ei...  8.96
# 833       918                                            Gintama  8.96
#
#                                                   Genres  \
# 3971   Action, Military, Adventure, Comedy, Drama, Ma...
# 15926  Action, Military, Mystery, Super Power, Drama,...
# ...
